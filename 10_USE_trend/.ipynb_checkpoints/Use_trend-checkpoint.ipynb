# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %% [markdown]
# - A trend is a long-term increase or decrease in the level of the time series.
# - In general, a systematic change in a time series that does not appear to be periodic is known as a trend.
#
# Two types:
#
# - Deterministic Trends: These are trends that consistently increase or decrease.
# - Stochastic Trends: These are trends that increase and decrease inconsistently.
#
#
# ##### Identifying a Trend:
# - You can plot time series data to see if a trend is obvious or not.
# - Create line plots of your data and inspect the plots for obvious trends.
# - Add linear and nonlinear trend lines to your plots and see if a trend is obvious.
#
#
# A time series with a trend is called non-stationary.
# - If a dataset does not have a trend or we successfully remove the trend, the dataset is said to be trend stationary.

# %%
#from pandas import datetime

# %%
def parser(x):
    return datetime.strptime('190'+x, '%Y-%m')

# %%
df = pd.read_csv('../Data/shampoo-sales.csv', header=0, index_col=0, parse_dates=True, squeeze=True, date_parser=parser)

df.plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
df.head()
# Out:
# Month
# 1901-01-01    266.0
# 1901-02-01    145.9
# 1901-03-01    183.1
# 1901-04-01    119.3
# 1901-05-01    180.3
# Name: Sales, dtype: float64

# %%
df1 = pd.read_csv('../Data/shampoo-sales.csv',index_col=0,parse_dates=True, date_parser=parser)
df1.head()
# Out:
#             Sales
# Month
# 1901-01-01  266.0
# 1901-02-01  145.9
# 1901-03-01  183.1
# 1901-04-01  119.3
# 1901-05-01  180.3

# %%
X=df1['Sales'].values
X
# Out:
# array([266. , 145.9, 183.1, 119.3, 180.3, 168.5, 231.8, 224.5, 192.8,
#        122.9, 336.5, 185.9, 194.3, 149.5, 210.1, 273.3, 191.4, 287. ,
#        226. , 303.6, 289.9, 421.6, 264.5, 342.3, 339.7, 440.4, 315.9,
#        439.3, 401.3, 437.4, 575.5, 407.6, 682. , 475.3, 581.3, 646.9])

# %%
import matplotlib.pyplot as plt

diff=list()
for i in range(1, len(X)):
    value=X[i]-X[i-1]
    diff.append(value)

plt.plot(diff);

# %%
diff
# Out:
# [-120.1,
#  37.19999999999999,
#  -63.8,
#  61.000000000000014,
#  -11.800000000000011,
#  63.30000000000001,
#  -7.300000000000011,
#  -31.69999999999999,
#  -69.9,
#  213.6,
#  -150.6,
#  8.400000000000006,
#  -44.80000000000001,
#  60.599999999999994,
#  63.20000000000002,
#  -81.9,
#  95.6,
#  -61.0,
#  77.60000000000002,
#  -13.700000000000045,
#  131.70000000000005,
#  -157.10000000000002,
#  77.80000000000001,
#  -2.6000000000000227,
#  100.69999999999999,
#  -124.5,
#  123.40000000000003,
#  -38.0,
#  36.099999999999966,
#  138.10000000000002,
#  -167.89999999999998,
#  274.4,
#  -206.7,
#  105.99999999999994,
#  65.60000000000002]

# %%
from statsmodels.tsa.statespace.tools import diff
df1['d1_Sales'] = diff(df1['Sales'],k_diff=1)

df1['d1_Sales'].plot(title="FIRST DIFFERENCE DATA").autoscale(axis='x',tight=True);

# %%
df1['d1_Sales'].head()
# Out:
# Month
# 1901-01-01      NaN
# 1901-02-01   -120.1
# 1901-03-01     37.2
# 1901-04-01    -63.8
# 1901-05-01     61.0
# Name: d1_Sales, dtype: float64

# %% [markdown]
# # Detrend by Model Fitting
# ## Fit linear model

# %%
X=[i for i in range(0, len(df1['Sales']))]

# %%
X=np.reshape(X,(len(X),1))
len(X)
# Out:
# 36

# %%
y=df1['Sales'].values

# %%
y
# Out:
# array([266. , 145.9, 183.1, 119.3, 180.3, 168.5, 231.8, 224.5, 192.8,
#        122.9, 336.5, 185.9, 194.3, 149.5, 210.1, 273.3, 191.4, 287. ,
#        226. , 303.6, 289.9, 421.6, 264.5, 342.3, 339.7, 440.4, 315.9,
#        439.3, 401.3, 437.4, 575.5, 407.6, 682. , 475.3, 581.3, 646.9])

# %%
from sklearn.linear_model import LinearRegression

model=LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
trend=model.predict(X)
plt.plot(trend);
plt.plot(y);

# %%
detrend=[y[i]-trend[i] for i in range(0,len(y))]
plt.plot(detrend);

# %%
plt.plot(diff);
plt.plot(detrend);
